# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

citydatadf = pd.read_csv(city_data_to_load)
ridedatadf = pd.read_csv(ride_data_to_load)


# Read the City and Ride Data
print(citydatadf.head())
print(ridedatadf.head())
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
#Combine the data into a single dataset

masterdf = pd.merge(citydatadf,ridedatadf, on='city')
# Display the data table for preview
masterdf.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %% [markdown]
# # Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types


#City Totals
average_fair = masterdf.groupby('city')['fare'].mean()
total_rides = masterdf.groupby('city')['ride_id'].count()
total_drivers = masterdf.groupby('city')['driver_count'].mean()
city_type = citydatadf.set_index('city')['type']


#create city df with summary totals

pyber_cities_df = pd.DataFrame({'Average Fare':average_fair,
                                'Total Rides': total_rides,
                                'Total Drivers':total_drivers,
                               'City Type': city_type})
print(pyber_cities_df.head())
#Create city types df for scatter plot
urban = pyber_cities_df.loc[pyber_cities_df["City Type"]== 'Urban']
suburban = pyber_cities_df.loc[pyber_cities_df["City Type"]== 'Suburban']
rural = pyber_cities_df.loc[pyber_cities_df["City Type"]== 'Rural']

# Build the scatter plots for each city types
plt.scatter(urban['Total Rides'],urban['Average Fare'],color='Gold',label = 'Urban',s=urban['Total Drivers']*10, alpha =.5, linewidth= .5,edgecolors = 'black')
plt.scatter(suburban['Total Rides'],suburban['Average Fare'],color='Coral',label = 'Surban',s=suburban['Total Drivers']*10,alpha =.5, linewidth= .5,edgecolors = 'black')
plt.scatter(rural['Total Rides'],rural['Average Fare'],color='SkyBlue',label = 'Rural',s=rural['Total Drivers']*10,alpha =.5, linewidth= .5,edgecolors = 'black')

# Incorporate the other graph properties
plt.title("Pyber Ride Sharing Data")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")


# Create a legend
plt.legend(loc='best')

# Incorporate a text label regarding circle size
plt.text(45,30," Note: Circle size correlates with driver count per city")

# Save Figure
plt.savefig("Images/Pyber Scatter(Huy).jpg")
plt.show()
# Out:
#                Average Fare  Total Rides  Total Drivers City Type
# Amandaburgh       24.641667           18             12     Urban
# Barajasview       25.332273           22             26     Urban
# Barronchester     36.422500           16             11  Suburban
# Bethanyland       32.956111           18             22  Suburban
# Bradshawfurt      40.064000           10              7     Rural

# %% [markdown]
# # Total Fares by City Type

# %%
city_fare = masterdf.groupby(['type'])['fare'].sum()
city_fare
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
colors = ["gold", "lightskyblue", "lightcoral"]
labels = city_fare.index
explode = [.1,0,0]

plt.pie(city_fare,colors=colors,labels=labels,explode=explode,autopct = "%1.1f%%")
plt.title('% of Total Fares by City Type')
plt.axis("equal")
plt.legend(loc='lower right')

plt.savefig("Images/Total Fares by City Type_PIE(Huy).jpg")
print(city_fare)
plt.show()
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %% [markdown]
# # Total Rides by City Type

# %%
ride_total = masterdf.groupby(['type'])['ride_id'].count()

colors = ["gold", "lightskyblue", "lightcoral"]
labels = ride_total.index
explode = [.1,0,0]

plt.pie(ride_total,colors=colors,labels=labels,explode=explode,autopct = "%1.1f%%")
plt.title('% of Total Rides by City Type')
plt.axis("equal")
plt.legend(loc='lower right')

plt.savefig("Images/Total Rides by City Type_PIE(Huy).jpg")
print(ride_total)
plt.show()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %% [markdown]
# # Total Drivers by City Type

# %%
driver_total = masterdf.groupby(['type'])['driver_count'].mean()

colors = ["gold", "lightskyblue", "lightcoral"]
labels = driver_total.index
explode = [.1,0,0]

plt.pie(driver_total,colors=colors,labels=labels,explode=explode,autopct = "%1.1f%%")
plt.title('% of Total Drivers by City Type')
plt.axis("equal")
plt.legend(loc='lower right')


plt.savefig("Images/Total Drivers by City Type_PIE(Huy).jpg")
print(driver_total)
plt.show()
# Out:
# type
# Rural        4.296000
# Suburban    13.712000
# Urban       36.678154
# Name: driver_count, dtype: float64
